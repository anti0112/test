# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## ШАГ 4
# Редактировать файл:
#
# Отредактируем файл с текстом
#
# ```
# Глава 1
#
# Жила на окраине леса маленькая собачка.
# Она была очень умна.
# Каждое утро она отправлялась на прогулку.
# Она уходила с утра до вечера, возвращалась домой
# и ложилась спать.
# Все говорили ей, что она стала совсем большая,
# но она не понимала, что стала умнее.
# ```

# %% [markdown]
# ## Шаг 5<br>
# #### Делаем коммит.<br>
# #### Сделаем коммит с сообщением: 'created chapter 1'<br>

# %% [markdown]
# ## ШАГ 6<br>
# #### Добавить новую главу и закомитить ее(коммит назвать): `chapter 2`

# %% [markdown]
# Ссылка для скачивания git на компьютер:
#
# https://git-scm.com/download/win
